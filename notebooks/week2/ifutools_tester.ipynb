# %%
import numpy as np
import matplotlib.pyplot as plt
from mpdaf.obj import Cube
from astropy.units import u
from astropy.coordinates import SkyCoord
import sys
import plotfancy as pf
from matplotlib.patches import Circle
from astropy.visualization import ZScaleInterval

pf.housestyle_rcparams()

from IFU_tools import analyse_galaxy_spectrum

# %%
CUBE_PATH = '../../cubes/macs0159m34_COMBINED_CUBE_MED_FINAL.fits'
# CUBE_PATH = '../../cubes/s780_COMBINED_CUBE_MED_FINAL.fits'
TITLE = 'MACS'
RADIUS_ARCSEC = .6
Z = 0.249

ra_hms = '01h59m04.03s'
dec_dms = '-34d13m03.8s'
coords = SkyCoord(ra_hms, dec_dms, frame='icrs')
RA_DEG = coords.ra.deg
DEC_DEG = coords.dec.deg

# %%
spec, lf1 = analyse_galaxy_spectrum(
    cube_path=CUBE_PATH,
    ra=RA_DEG,
    dec=DEC_DEG,
    radius=RADIUS_ARCSEC,
    title=TITLE,
    z_guess=Z,
    pref=ra_hms.replace('.','p')+'_'+dec_dms.replace('.','p')
)
# Out:
# [INFO] 36 spaxels used
# Loading datacube: ../../cubes/macs0159m34_COMBINED_CUBE_MED_FINAL.fits...
# Successfully loaded cube. Dimensions: (3681, 314, 329)
#
# Extracting spectrum at (RA, Dec) = (29.775208, -34.217722) with a 0.6" radius aperture.
# Extraction complete.
#
# Measuring spectroscopic redshift...
#   - Hbeta: Found at 8210.37 \AA, z = 0.68891
#   - OIII_5007: Found at 8456.15 \AA, z = 0.68892
#   - Halpha: Fit failed near 11091.13 \AA.
#
# Measured Redshift z = 0.68892 ± 0.00000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/durham/eelgs/notebooks/week2/IFU_tools.py:104, in fit_emission_lines(spec_rest)
#     103 try:
# --> 104     line_fits[name] = spec_rest.gauss_fit(lmin=(wave - 15), lmax=(wave + 15), plot=False)
#     105 except Exception:
#
# File ~/Documents/durham/eelgs/.venv/lib/python3.13/site-packages/mpdaf/obj/spectrum.py:1423, in Spectrum.gauss_fit(self, lmin, lmax, lpeak, flux, fwhm, cont, peak, spline, weight, plot, plot_factor, unit, fix_lpeak)
#    1422 if not isinstance(spec, Spectrum):
# -> 1423     raise ValueError('Gaussian fit outside spectrum wavelength range')
#    1424 data = spec._interp_data(spline)
#
# ValueError: Gaussian fit outside spectrum wavelength range
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 spec, lf1 = analyse_galaxy_spectrum(
#       2     cube_path=CUBE_PATH,
#       3     ra=RA_DEG,
#       4     dec=DEC_DEG,
#       5     radius=RADIUS_ARCSEC,
#       6     title=TITLE,
#       7     z_guess=Z,
#       8     pref=ra_hms.replace('.','p')+'_'+dec_dms.replace('.','p')
#       9 )
#
# File ~/Documents/durham/eelgs/notebooks/week2/IFU_tools.py:188, in analyse_galaxy_spectrum(cube_path, ra, dec, radius, z_guess, title, pref)
#     186 z, z_err = measure_redshift(spec, z_guess)
#     187 spec_rest = deredshift_spectrum(spec, z)
# --> 188 line_fits = fit_emission_lines(spec_rest)
#     189 plot_line_fits(spec_rest, line_fits, z, z_err, title, pref)
#     190 return spec, line_fits
#
# File ~/Documents/durham/eelgs/notebooks/week2/IFU_tools.py:106, in fit_emission_lines(spec_rest)
#     104     line_fits[name] = spec_rest.gauss_fit(lmin=(wave - 15), lmax=(wave + 15), plot=False)
#     105 except Exception:
# --> 106     sub_spec = spec_rest.select_lambda(wave - 15, wave + 15)
#     107     if sub_spec is not None and sub_spec.shape[0] > 2:
#     108         continuum = np.mean(sub_spec.data)
#
# AttributeError: 'Spectrum' object has no attribute 'select_lambda'
