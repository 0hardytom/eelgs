# %%
import numpy as np
import matplotlib.pyplot as plt
from mpdaf.obj import Cube
from astropy.units import u
from astropy.coordinates import SkyCoord
import sys
import plotfancy as pf
from matplotlib.patches import Circle
from astropy.visualization import ZScaleInterval

pf.housestyle_rcparams()

from IFU_tools import analyse_galaxy_spectrum

# %%
# CUBE_PATH = '../../cubes/macs0159m34_COMBINED_CUBE_MED_FINAL.fits'
CUBE_PATH = '../../cubes/s780_COMBINED_CUBE_MED_FINAL.fits'
TITLE = 'abel'
RADIUS_ARCSEC = .6
Z = 0.67

ra_hms = '14h59m28.42s'
dec_dms = '-18d10m35.52s'
coords = SkyCoord(ra_hms, dec_dms, frame='icrs')
RA_DEG = coords.ra.deg
DEC_DEG = coords.dec.deg

# %%
spec, lf1 = analyse_galaxy_spectrum(
    cube_path=CUBE_PATH,
    ra=RA_DEG,
    dec=DEC_DEG,
    radius=RADIUS_ARCSEC,
    title=TITLE,
    z_guess=Z,
    pref=ra_hms.replace('.','p')+'_'+dec_dms.replace('.','p')
)
# Out:
# Loading datacube: ../../cubes/s780_COMBINED_CUBE_MED_FINAL.fits...
# Successfully loaded cube. Dimensions: (3682, 315, 361)
#
# Extracting spectrum at (RA, Dec) = (224.868417, -18.176533) with a 0.6" radius aperture.
# [INFO] 36 spaxels used
# Extraction complete.
#
# Measuring spectroscopic redshift...
#   - Hbeta: Found at 8116.83 \AA, z = 0.66967
#   - OIII_5007: Found at 8359.91 \AA, z = 0.66970
#   - Halpha: Fit failed near 10959.88 \AA.
#
# Measured Redshift z = 0.66969 ± 0.00001
# [OIII]/Hβ = 3.958 +/- 0.323
# log([OIII]/Hβ) = 0.598 +/- 0.035
#
# [NII]/Halpha could not be calculated.
