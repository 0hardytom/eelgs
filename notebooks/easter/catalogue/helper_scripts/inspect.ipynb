# %%
from astropy.io import ascii,fits
from astropy.table import Table

# %%
hdul = fits.open('filter_list.fits')

# %%
hdul[2].data
# Out:
# FITS_rec([(4750., 0.   ), (4800., 0.03 ), (4850., 0.084), (4900., 0.163),
#           (4950., 0.301), (5000., 0.458), (5050., 0.63 ), (5100., 0.78 ),
#           (5150., 0.895), (5200., 0.967), (5250., 0.997), (5300., 1.   ),
#           (5350., 0.988), (5400., 0.958), (5450., 0.919), (5500., 0.877),
#           (5550., 0.819), (5600., 0.765), (5650., 0.711), (5700., 0.657),
#           (5750., 0.602), (5800., 0.545), (5850., 0.488), (5900., 0.434),
#           (5950., 0.386), (6000., 0.331), (6050., 0.289), (6100., 0.25 ),
#           (6150., 0.214), (6200., 0.181), (6250., 0.151), (6300., 0.12 ),
#           (6350., 0.093), (6400., 0.069), (6450., 0.051), (6500., 0.036),
#           (6550., 0.027), (6600., 0.021), (6650., 0.018), (6700., 0.016),
#           (6750., 0.014), (6800., 0.012), (6850., 0.011), (6900., 0.01 ),
#           (6950., 0.009), (7000., 0.008), (7050., 0.007), (7100., 0.006),
#           (7150., 0.005), (7200., 0.004), (7250., 0.003), (7300., 0.002),
# ...
