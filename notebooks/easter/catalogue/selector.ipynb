# %%
from astropy.io import ascii
from astropy.table import Table,vstack
import numpy as np
from glob import glob
from astropy.coordinates import SkyCoord
from astropy.constants import c as speedoflight
import astropy.units as u
from mpdaf.obj import Cube
import plotfancy as pf
pf.housestyle_rcparams()
# Out:
# True

# %%
MASTER1 = Table(ascii.read('MASTER.csv'))
MASTER2 = Table(ascii.read('MASTER_preLSD.csv'))

columns = [
    'angdisp',
    'foreground',
    'cluster_member',
    'lensed',
    'Z_dir',
    'Z_dir_e',
    'Z_j19',
    'Z_j19_e',
    'R23',
    'R23_e',
    'mean_vel_disp',
    'sterr_vel_disp',
]
MASTER2.remove_columns(columns)
filters = [
    'WFC3_F502N',
    'WFC3_F606W',
    'WFC3_F625W',
    'WFC3_F656N',
    'WFC3_F775W',
]
MASTER1.remove_columns(filters)
for M in [MASTER1,MASTER2]:
    M = M[np.isfinite(M['oiii5007_ew'])]
    M = M[(M['oiii4959_flux']/M['oiii5007_flux'])>0.1]

MASTER = vstack([MASTER1,MASTER2])

# %%
MASTER.sort('oiii5007_flux')
peas = MASTER[MASTER['oiii5007_ew']>100]
peas.sort('oiii5007_ew',reverse=True)

# %%
# Table(MASTER[-1]).write('../prospector_1/sedrunNEW.csv', overwrite=True)
peas.write('../prospector_1/sedrunNEW.csv', overwrite=True)

# %%
MASTER
# Out:
# <Table length=309>
#                object_id                 ...   sterr_vel_disp
#                  str40                   ...      float64
# ---------------------------------------- ... ------------------
#            34d18m23pt595s-52d45m52pt899s ... 13.905873435448262
#    69d45m33pt88085519s5d20m43pt64429647s ...                 --
#  61d05m07pt33321354s-27d02m53pt08840245s ...                 --
#  91d28m28pt76168372s-35d18m07pt54941805s ...                 --
#     8d44m29pt97104791s2d34m00pt39179231s ...                 --
#  88d21m52pt47042617s-33d42m43pt39125989s ...                 --
#   135d09m01pt29197837s20d53m29pt0887543s ...                 --
#  72d20m32pt54167568s-28d49m36pt65181981s ...                 --
#    69d44m47pt02148888s7d16m31pt65143843s ...                 --
#                                      ... ...                ...
#   82d13m07pt1333634s-39d27m50pt76770368s ...                 --
#      8d28m41pt604992s-7d51m59pt20098902s ...                 --
#            16d23m41pt415s-24d38m36pt656s ...  8.275077441815633
#  16d23m41pt80164201s-24d38m36pt18549406s ...                 --
#               8d28m41pt88s-7d51m59pt549s ...  6.966739022947753
# 224d52m16pt41356234s-18d10m42pt80767292s ...                 --
#  83d14m26pt36626535s-37d01m32pt91263786s ...                 --
#  36d28m16pt31991583s-41d54m50pt94375995s ...                 --
#  77d34m26pt41964476s-45d19m21pt89816852s ...                 --
#  86d46m00pt55633295s-39d04m40pt73068874s ...                 --

# %%
row = peas[0]
name = row['name']

allfiles = glob('/Volumes/Expansion/exp_thardy/cubes/*.fits')+glob('/Volumes/Expansion/exp_thardy/cubes_new/*.fits')
filedir = 'BLANK'
for a in allfiles:
    if name in a:
        filedir = a
    
coord = SkyCoord(ra=row['ra'], dec=row['dec'], unit=u.deg)
cube = Cube(filedir)
spectrum = cube.aperture((coord.dec.deg,coord.ra.deg),2)
spectrum = spectrum.resample(2.5)
conv_factor = (1.0 / speedoflight).to(u.Jy * u.s * u.cm**2 / (u.erg *u.AA))
flux_lambda = spectrum.data.data*u.erg/(u.AA*u.s*u.cm**2)*1e-20
wavelength = spectrum.wave.coord()*u.AA
flux_jansky = conv_factor * flux_lambda * wavelength**2
flux_maggie = flux_jansky/3631
# Out:
# [INFO] 400 spaxels used

# %%
fig, ax = pf.create_plot((8,2))

mask = np.isfinite(flux_maggie.value)&(flux_maggie.value>0)

ax.plot(wavelength[mask]/(1+row['z']),flux_maggie[mask])

pf.fix_plot([ax])
# Out:
# True

# %%
row['oiii4959_centroid']
# Out:
# np.float64(4958.882725711956)

# %%
row['object_id']
# Out:
# np.str_('86d46m00pt55633295s-39d04m40pt73068874s')

# %%
mask = (peas['flux_Spitzer_I2_4.5']>0)&(peas['flux_Spitzer_I1_3.6']>0)
# Out:
# <Table length=62>
#               object_id                ...      WFC3_F775W
#                 str40                  ...       float64
# -------------------------------------- ... -------------------
#           6d23m36pt795s-12d22m50pt684s ...                  --
#            8d51m41pt55s-20d15m44pt023s ...                  --
#            6d51m52pt995s26d07m16pt522s ...                  --
#            4d46m35pt34s-20d26m04pt362s ...                  --
#           10d12m52pt83s-44d08m06pt786s ...                  --
# 88d19m48pt8284935s-33d42m42pt89990813s ... 0.03876664310991375
#             4d54m58pt005s3d36m09pt248s ...                  --
#            4d44m59pt43s-40d51m24pt731s ...                  --
#           2d55m43pt275s-15d23m04pt376s ...                  --
#                                    ... ...                 ...
#              4d38m38pt61s16d26m31pt04s ...                  --
#           6d23m02pt565s-12d23m18pt413s ...                  --
# 82d13m07pt1333634s-39d27m50pt76770368s ...  0.6330103772742964
#             0d47m51pt42s-6d05m58pt798s ...                  --
#             8d27m53pt28s-7d52m14pt418s ...                  --
#              8d44m45pt72s2d34m00pt454s ...                  --
#             24d59m51pt81s-5d54m55pt49s ...                  --
#           10d51m32pt73s-20d37m36pt819s ...                  --
#           34d19m22pt71s-52d46m02pt865s ...                  --
#              8d36m51pt21s2d25m03pt878s ...                  --
